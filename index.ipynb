# %% [markdown]
# # Web Scraping with Beautiful Soup - Lab

# %% [markdown]
# ## Introduction
#
# Now that you've read and seen some docmentation regarding the use of Beautiful Soup, its time to practice and put that to work! In this lab you'll formalize some of our example code into functions and scrape the lyrics from an artist of your choice.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Scrape Static webpages
# * Select specific elements from the DOM

# %% [markdown]
# ## Link Scraping
#
# Write a function to collect the links to each of the song pages from a given artist page.

# %%
#Starter Code

from bs4 import BeautifulSoup
import requests
import pandas as pd

url= 'https://www.azlyrics.com/f/falloutboy.html'


html_page = requests.get(url) #Make a get request to retrieve the page
soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing
albums = soup.find_all('div', attrs={'class':'album'})

# %%
allsongs = albums[0].findNextSiblings('a')

# %%
def scrapesongs(url):

    html_page = requests.get(url) #Make a get request to retrieve the page
    soup = BeautifulSoup(html_page.content, 'html.parser') #Pass the page contents to beautiful soup for parsing
    albums = soup.find_all('div', attrs={'class':'album'})
    
    data = []

    for album_n in range(len(albums)):
        if album_n == len(albums)-1:
            cur_album = albums[album_n]
            album_songs = cur_album.findNextSiblings('a')
            for song in album_songs:
                page = song.get('href')
                title = song.text
                album = cur_album.text
                data.append((title, page, album))
        else:
            cur_album = albums[album_n]
            next_album = albums[album_n+1]
            saca = cur_album.findNextSiblings('a') #songs after current album
            sbna = next_album.findPreviousSiblings('a') #songs before next album
            album_songs = [song for song in saca if song in sbna] #album songs are those listed after the current album but before the next one!
            for song in album_songs:
                page = song.get('href')
                title = song.text
                album = cur_album.text
                lyrics = getlyrics(page)
                print(title)
                data.append((title, page, album, lyrics))
    return data

# %%
df = pd.DataFrame(scrapesongs('https://www.azlyrics.com/f/falloutboy.html'),columns=('name', 'link', 'album', 'lyrics'))

# %%
df
# Out:
#                                                   name  \
# 0                                    Honorable Mention
# 1                                Calm Before The Storm
# 2                          Switchblades And Infidelity
# 3                                       Pretty In Punk
# 4                                           Growing Up
# 5    The World's Not Waiting (For Five Tired Boys I...
# 6                                 Short, Fast And Loud
# 7                                      Moving Pictures
# 8    Parker Lewis Can't Lose (But I'm Gonna Give It...
# 9    Tell That Mick He Just Made My List Of Things ...
# 10                                     Dead On Arrival
# 11              Grand Theft Autumn / Where Is Your Boy
# 12                                            Saturday
# 13                              Homesick At Space Camp
# 14   Sending Postcards From A Plane Crash (Wish You...
# 15                         Chicago Is So Two Years Ago
# 16                      The Pros And Cons Of Breathing
# 17                                      Grenade Jumper
# 18                               Calm Before The Storm
# 19            Reinventing The Wheel To Run Myself Over
# 20                 The Patron Saint Of Liars And Fakes
# 21                My Heart Is The Worst Kind Of Weapon
# 22   "It's Not A Side Effect Of The Cocaine, I Am T...
# 23           Nobody Puts Baby In The Corner (Acoustic)
# 24                             Love Will Tear Us Apart
# 25   Grand Theft Autumn / Where Is Your Boy (Acoustic)
# 26   Our Lawyer Made Us Change The Name Of This Son...
# 27              Of All The Gin Joints In All The World
# 28                                        Dance, Dance
# 29                              Sugar We're Going Down
# ..                                                 ...
# 134                         ALPHAdog and OMEGAlomaniac
# 135                                       American Boy
# 136                          Austin, We Have A Problem
# 137                                        Basket Case
# 138   Catch Me If You Can / Proclamation Of Emaciation
# 139                                   Champion (Remix)
# 140                             Fellowship Of The Nerd
# 141                         From Now On We Are Enemies
# 142                      Ghostbusters (I'm Not Afraid)
# 143      Guilty As Charged (Tell Hip Hop I'm Literate)
# 144                                        Hand Of God
# 145             I Wan'na Be Like You (The Monkey Song)
# 146         I Wanna Dance With Somebody (Who Loves Me)
# 147                         I Write Sins Not Tragedies
# 148                               Irresistible (Remix)
# 149                     Lake Effect Kid (Demo Version)
# 150      My Songs Know What You Did In The Dark (Demo)
# 151                                            Roxanne
# 152              Saturday Night's Alright For Fighting
# 153                               Save Your Generation
# 154                                            Star 67
# 155                                        Start Today
# 156                  The Last Of The Real Ones (Remix)
# 157      This Ain't A Scene, It's An Arms Race (Remix)
# 158                                     Turnpike Gates
# 159                        Uma Thurman (Didrick Remix)
# 160                                        Uptown Funk
# 161                  We Don't Take Hits, We Write Them
# 162                                       What's This?
# 163                            Yule Shoot Your Eye Out
#
#                                                   link  \
# 0           ../lyrics/falloutboy/honorablemention.html
# 1    ../lyrics/falloutboy/calmbeforethestorm96412.html
# 2    ../lyrics/falloutboy/switchbladesandinfidelity...
# 3               ../lyrics/falloutboy/prettyinpunk.html
# 4                  ../lyrics/falloutboy/growingup.html
# 5    ../lyrics/falloutboy/theworldsnotwaitingforfiv...
# 6           ../lyrics/falloutboy/shortfastandloud.html
# 7             ../lyrics/falloutboy/movingpictures.html
# 8    ../lyrics/falloutboy/parkerlewiscantlosebutimg...
# 9    ../lyrics/falloutboy/tellthatmickhejustmademyl...
# 10             ../lyrics/falloutboy/deadonarrival.html
# 11   ../lyrics/falloutboy/grandtheftautumnwhereisyo...
# 12                  ../lyrics/falloutboy/saturday.html
# 13       ../lyrics/falloutboy/homesickatspacecamp.html
# 14   ../lyrics/falloutboy/sendingpostcardsfromaplan...
# 15    ../lyrics/falloutboy/chicagoissotwoyearsago.html
# 16   ../lyrics/falloutboy/theprosandconsofbreathing...
# 17             ../lyrics/falloutboy/grenadejumper.html
# 18        ../lyrics/falloutboy/calmbeforethestorm.html
# 19   ../lyrics/falloutboy/reinventingthewheeltorunm...
# 20   ../lyrics/falloutboy/thepatronsaintofliarsandf...
# 21   ../lyrics/falloutboy/myheartistheworstkindofwe...
# 22   ../lyrics/falloutboy/itsnotasideeffectofthecoc...
# 23   ../lyrics/falloutboy/nobodyputsbabyinthecorner...
# 24       ../lyrics/falloutboy/lovewilltearusapart.html
# 25   ../lyrics/falloutboy/grandtheftautumnwhereisyo...
# 26   ../lyrics/falloutboy/ourlawyermadeuschangethen...
# 27   ../lyrics/falloutboy/ofalltheginjointsinallthe...
# 28                ../lyrics/falloutboy/dancedance.html
# 29        ../lyrics/falloutboy/sugarweregoingdown.html
# ..                                                 ...
# 134  ../lyrics/falloutboy/alphadogandomegalomaniac....
# 135              ../lyrics/falloutboy/americanboy.html
# 136     ../lyrics/falloutboy/austinwehaveaproblem.html
# 137               ../lyrics/falloutboy/basketcase.html
# 138  ../lyrics/falloutboy/catchmeifyoucanproclamati...
# 139            ../lyrics/falloutboy/championremix.html
# 140      ../lyrics/falloutboy/fellowshipofthenerd.html
# 141    ../lyrics/falloutboy/fromnowonweareenemies.html
# 142  ../lyrics/falloutboy/ghostbustersimnotafraid.html
# 143  ../lyrics/falloutboy/guiltyaschargedtellhiphop...
# 144                ../lyrics/falloutboy/handofgod.html
# 145  ../lyrics/falloutboy/iwannabelikeyouthemonkeys...
# 146  ../lyrics/falloutboy/iwannadancewithsomebodywh...
# 147   ../lyrics/falloutboy/iwritesinsnottragedies.html
# 148        ../lyrics/falloutboy/irresistibleremix.html
# 149  ../lyrics/falloutboy/lakeeffectkiddemoversion....
# 150  ../lyrics/falloutboy/mysongsknowwhatyoudidinth...
# 151                  ../lyrics/falloutboy/roxanne.html
# 152  ../lyrics/falloutboy/saturdaynightsalrightforf...
# 153       ../lyrics/falloutboy/saveyourgeneration.html
# 154                   ../lyrics/falloutboy/star67.html
# 155               ../lyrics/falloutboy/starttoday.html
# 156  ../lyrics/falloutboy/thelastoftherealonesremix...
# 157  ../lyrics/falloutboy/thisaintasceneitsanarmsra...
# 158            ../lyrics/falloutboy/turnpikegates.html
# 159   ../lyrics/falloutboy/umathurmandidrickremix.html
# 160               ../lyrics/falloutboy/uptownfunk.html
# 161  ../lyrics/falloutboy/wedonttakehitswewritethem...
# 162                ../lyrics/falloutboy/whatsthis.html
# 163      ../lyrics/falloutboy/yuleshootyoureyeout.html
#
#                                                  album  \
# 0    album: "Fall Out Boy's Evening Out With Your G...
# 1    album: "Fall Out Boy's Evening Out With Your G...
# 2    album: "Fall Out Boy's Evening Out With Your G...
# 3    album: "Fall Out Boy's Evening Out With Your G...
# 4    album: "Fall Out Boy's Evening Out With Your G...
# 5    album: "Fall Out Boy's Evening Out With Your G...
# 6    album: "Fall Out Boy's Evening Out With Your G...
# 7    album: "Fall Out Boy's Evening Out With Your G...
# 8    album: "Fall Out Boy's Evening Out With Your G...
# 9              album: "Take This To Your Grave" (2003)
# 10             album: "Take This To Your Grave" (2003)
# 11             album: "Take This To Your Grave" (2003)
# 12             album: "Take This To Your Grave" (2003)
# 13             album: "Take This To Your Grave" (2003)
# 14             album: "Take This To Your Grave" (2003)
# 15             album: "Take This To Your Grave" (2003)
# 16             album: "Take This To Your Grave" (2003)
# 17             album: "Take This To Your Grave" (2003)
# 18             album: "Take This To Your Grave" (2003)
# 19             album: "Take This To Your Grave" (2003)
# 20             album: "Take This To Your Grave" (2003)
# 21   EP: "My Heart Will Always Be The B-Side To My ...
# 22   EP: "My Heart Will Always Be The B-Side To My ...
# 23   EP: "My Heart Will Always Be The B-Side To My ...
# 24   EP: "My Heart Will Always Be The B-Side To My ...
# 25   EP: "My Heart Will Always Be The B-Side To My ...
# 26            album: "From Under The Cork Tree" (2005)
# 27            album: "From Under The Cork Tree" (2005)
# 28            album: "From Under The Cork Tree" (2005)
# 29            album: "From Under The Cork Tree" (2005)
# ..                                                 ...
# 134                                       other songs:
# 135                                       other songs:
# 136                                       other songs:
# 137                                       other songs:
# 138                                       other songs:
# 139                                       other songs:
# 140                                       other songs:
# 141                                       other songs:
# 142                                       other songs:
# 143                                       other songs:
# 144                                       other songs:
# 145                                       other songs:
# 146                                       other songs:
# 147                                       other songs:
# 148                                       other songs:
# 149                                       other songs:
# 150                                       other songs:
# 151                                       other songs:
# 152                                       other songs:
# 153                                       other songs:
# 154                                       other songs:
# 155                                       other songs:
# 156                                       other songs:
# 157                                       other songs:
# 158                                       other songs:
# 159                                       other songs:
# 160                                       other songs:
# 161                                       other songs:
# 162                                       other songs:
# 163                                       other songs:
#
#                                                 lyrics
# 0    \n\r\nI served out my detention\r\nAnd in the ...
# 1    \n\r\nI sat outside my front window...this sto...
# 2    \n\r\nWalking out on the show is walking out o...
# 3    \n\r\nWalking off that stage tonight\r\nI know...
# 4    \n\r\nI dried my eyes, now I crust them with s...
# 5    \n\r\nThis might just be a waste of time\r\nth...
# 6    \n\r\nShe's shallow like the shoreline during ...
# 7    \n\r\nLast night I saw a movie\r\nand I though...
# 8    \n\r\nYou laughed off my affections\r\nWhile I...
# 9    \n\r\nLight that smoke, that one for giving up...
# 10   \n\r\nHope this is the last time 'cause I'd ne...
# 11   \n\r\nWhere is your boy tonight?\nI hope he is...
# 12   \n\r\nI'm good to go\r\nAnd I'm going nowhere ...
# 13   \n\r\nLanding on a runway in Chicago and I'm g...
# 14   \n\r\nI am such a sucker\nAnd I'm always the l...
# 15   \n\r\nMy heart is on my sleeve\nWear it like a...
# 16   \n\r\nBury me standing under your window with ...
# 17   \n\r\nMy heart ticks in beat with these kids t...
# 18   \n\r\nI sat outside my front window... this st...
# 19   \n\r\nI could walk this fine line between elat...
# 20   \n\r\nI'm holding out and I'm holding on \r\nt...
# 21   \n\r\nI spent most of last night dragging this...
# 22   \n\r\nWhy can you read me like no one else?\r\...
# 23   \n\r\nDrink down that Gin and Kerosene,\r\nAnd...
# 24   \n\r\nWhen routine bites hard\r\nand ambitions...
# 25   \n\r\nWhen I wake up, I'm willing to take my c...
# 26   \n\r\nBrothers and sisters put this record dow...
# 27   \n\r\n(oh, oh, oh, oh, oh)\n\nYou only hold me...
# 28   \n\r\nShe says she's no good with words but I'...
# 29   \n\r\nAm I more than you bargained for yet?\nI...
# ..                                                 ...
# 134                                               None
# 135                                               None
# 136                                               None
# 137                                               None
# 138                                               None
# 139                                               None
# 140                                               None
# 141                                               None
# 142                                               None
# 143                                               None
# 144                                               None
# 145                                               None
# 146                                               None
# 147                                               None
# 148                                               None
# 149                                               None
# 150                                               None
# 151                                               None
# 152                                               None
# 153                                               None
# 154                                               None
# 155                                               None
# 156                                               None
# 157                                               None
# 158                                               None
# 159                                               None
# 160                                               None
# 161                                               None
# 162                                               None
# 163                                               None
#
# [164 rows x 4 columns]

# %% [markdown]
# ## Text Scraping
# Write a secondary function that scrapes the lyrics for each song page.

# %%
#Example page
def getlyrics(url):
    extension = url[2:]
    baseurl= 'https://www.azlyrics.com'
    fullurl = baseurl + extension
    
    html_page = requests.get(fullurl)
    soup = BeautifulSoup(html_page.content, 'html.parser')
    lyrics = soup.find('div', attrs={'class':'ringtone'}).findNextSibling('div').text
    return lyrics

# %%
getlyrics('../lyrics/falloutboy/honorablemention.html')
# Out:
# "\n\r\nI served out my detention\r\nAnd in the end I got an honorable mention\n\r\nIn the movie of my life\r\nStarring you\r\nInstead of me\n\r\nWhen the moonlight\r\nHits your bright eyes I go blind\r\nAnd maybe next time\r\nI'll remember not to tell you something stupid like I'll never leave your side\n\r\nLike the oldest movie I ever saw was the one we wrote together\r\nI said I hate you but I'd never change a thing\r\nI can be your John Cusack\n\r\nI burnt out\r\nMy defensive\r\nNow everything I say is taken as offensive\n\r\nIn the movie of my life (movie of my life.. yeah)\r\nStarring you\r\nInstead of me\n\r\nWhen the moonlight\r\nHits your bright eyes I go blind\r\nAnd maybe next time\r\nI'll remember not to tell you something stupid like I'll never leave your side\n\r\nLike the oldest movie I ever saw was the one we wrote together\r\nI said I hate you but I'd never change a thing\r\nI can be your John Cusack\n\r\nOldest movie I ever saw was the one we wrote together\r\nI said I hate you but I'd never change a thing\r\nI can be your John Cusack\r\nBe your John Cusack \r\nI can be your John Cusack\n"

# %% [markdown]
# ## Synthesizing
# Create a script using your two functions above to scrape all of the song lyrics for a given artist.

# %%
#Use this block for your code!

# %% [markdown]
# ## Visualizing
# Generate two bar graphs to compare lyrical changes for the artist of your chose. For example, the two bar charts could compare the lyrics for two different songs or two different albums.

# %%
#Use this block for your code!

# %% [markdown]
# ## Level - Up
#
# Think about how you structured the data from your web scraper. Did you scrape the entire song lyrics verbatim? Did you simply store the words and their frequency counts, or did you do something else entirely? List out a few different options for how you could have stored this data. What are advantages and disadvantages of each? Be specific and think about what sort of analyses each representation would lend itself to.

# %%
#Use this block for your code!

# %% [markdown]
# ## Summary

# %% [markdown]
# Congratulations! You've now practiced your Beautiful Soup knowledge!
